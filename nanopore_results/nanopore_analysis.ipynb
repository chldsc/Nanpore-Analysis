# %%
import pysam
import numpy as np
import matplotlib.pyplot as plt
from freq_analysis import match_percentage, frequency_pipeline, threshold_processor, itr_classifier, egfp_cassette_by_qpcr

# %% [markdown]
# # 5' ITR

# %% [raw]
# minimap2 -ax map-ont --MD --secondary=no A.fasta 77XK98_1_New_addgene_AAV9-CAG-EGFP.fastq | samtools view -b -F 2304 -o addgene_temp.bam -
# samtools sort addgene_temp.bam -o addgene_nanopore.bam
# samtools calmd -b addgene_nanopore.bam A.fasta > addgene_nanopore_md.bam
# samtools index addgene_nanopore_md.bam

# %% [raw]
# minimap2 -ax map-ont --MD --secondary=no B.fasta DVX9YH_1_wt-ITR_AAV9_NEW_small_prep.fastq | samtools view -b -F 2304 -o wt_temp.bam -
# samtools sort wt_temp.bam -o wt_nanopore.bam
# samtools calmd -b wt_nanopore.bam B.fasta > wt_nanopore_md.bam
# samtools index wt_nanopore_md.bam

# %% [raw]
# minimap2 -ax map-ont --MD --secondary=no C.fasta DVX9YH_2_dBC-ITR_AAV9_small_prepx5_pool.fastq | samtools view -b -F 2304 -o dbc_temp.bam -
# samtools sort dbc_temp.bam -o dbc_nanopore.bam
# samtools calmd -b dbc_nanopore.bam C.fasta > dbc_nanopore_md.bam
# samtools index dbc_nanopore_md.bam

# %% [raw]
# minimap2 -ax map-ont --MD --secondary=no B.fasta 77XK98_2_wt-ITR_AAV9_no_PmlI_small_prep.fastq | samtools view -b -F 2304 -o wt_nopmll_temp.bam -
# samtools sort wt_nopmll_temp.bam -o wt_nopmll_nanopore.bam
# samtools calmd -b wt_nopmll_nanopore.bam B.fasta > wt_nopmll_nanopore_md.bam
# samtools index wt_nopmll_nanopore_md.bam

# %% [raw]
# minimap2 -ax map-ont --MD --secondary=no C.fasta 77XK98_3_dBC-ITR_AAV9_no_PmlI_small_prep.fastq | samtools view -b -F 2304 -o dbc_nopmll_temp.bam -
# samtools sort dbc_nopmll_temp.bam -o dbc_nopmll_nanopore.bam
# samtools calmd -b dbc_nopmll_nanopore.bam C.fasta > dbc_nopmll_nanopore_md.bam
# samtools index dbc_nopmll_nanopore_md.bam

# %%
#nanopore_addgene
filtered_count = 4862
bamfile = "77XK98_fastq/addgene_nanopore_md.bam"
contig = "A-addgene-plasmid-37825-sequence-448204"
start_region = 2459
end_region = 2588
start_contig = 0
end_contig = 5440
frequency_pipeline(bamfile, contig, start_region, end_region, filtered_count, start_contig, end_contig)
# Out:
# Unmapped Reads: 0
# Zero Length Reads: 0
# Total Reads Analyzed: 4862
# Reads Absent from Contig: 0
# Total Reads Contig: 4862

# %%
#WT_Nanopore
bamfile = "DVX9YH_fastq/wt_nanopore_md.bam"
contig = "B-synITRWT"
filtered_count = 4351 
start_region = 195
end_region = 339
start_contig = 0
end_contig = 4949
frequency_pipeline(bamfile, contig, start_region, end_region, filtered_count, start_contig, end_contig, filtered_count)
# Out:
# Unmapped Reads: 0
# Zero Length Reads: 0
# Total Reads Analyzed: 4351
# Reads Absent from Contig: 0
# Total Reads Contig: 4351

# %%
bamfile = "DVX9YH_fastq/dbc_nanopore_md.bam"
contig = "C-deltaBC-ITR"
filtered_count = 1585 
start_region = 195
end_region = 305
start_contig = 0
end_contig = 4949
frequency_pipeline(bamfile, contig, start_region, end_region, filtered_count, start_contig, end_contig, filtered_count)
# Out:
# Unmapped Reads: 0
# Zero Length Reads: 0
# Total Reads Analyzed: 1585
# Reads Absent from Contig: 0
# Total Reads Contig: 1585

# %%
#WT_Nanopore_nopmll
bamfile = "77XK98_fastq/wt_nopmll_nanopore_md.bam"
contig = "B-synITRWT"
filtered_count = 4323
start_region = 195
end_region = 339
start_contig = 0
end_contig = 4949
frequency_pipeline(bamfile, contig, start_region, end_region, filtered_count, start_contig, end_contig, filtered_count)
# Out:
# Unmapped Reads: 0
# Zero Length Reads: 0
# Total Reads Analyzed: 4323
# Reads Absent from Contig: 0
# Total Reads Contig: 4323

# %%
#dBC_Nanopore_nopmll
bamfile = "77XK98_fastq/dbc_nopmll_nanopore_md.bam"
contig = "C-deltaBC-ITR"
filtered_count = 2016
start_region = 195
end_region = 305
start_contig = 0
end_contig = 4949
frequency_pipeline(bamfile, contig, start_region, end_region, filtered_count, start_contig, end_contig, filtered_count)
# Out:
# Unmapped Reads: 0
# Zero Length Reads: 0
# Total Reads Analyzed: 2016
# Reads Absent from Contig: 0
# Total Reads Contig: 2016

# %% [markdown]
# # 3' ITR

# %%
#nanopore_addgene
filtered_count = 4862
bamfile = "77XK98_fastq/addgene_nanopore_md.bam"
contig = "A-addgene-plasmid-37825-sequence-448204"
start_region = 5255
end_region = 5384
start_contig = 0
end_contig = 5440
frequency_pipeline(bamfile, contig, start_region, end_region, filtered_count, start_contig, end_contig)
# Out:
# Unmapped Reads: 0
# Zero Length Reads: 0
# Total Reads Analyzed: 4862
# Reads Absent from Contig: 0
# Total Reads Contig: 4862

# %%
#WT_Nanopore
bamfile = "DVX9YH_fastq/wt_nanopore_md.bam"
contig = "B-synITRWT"
filtered_count = 4351 
start_region = 2925
end_region = 3069
start_contig = 0
end_contig = 5018
frequency_pipeline(bamfile, contig, start_region, end_region, filtered_count, start_contig, end_contig, filtered_count)
# Out:
# Unmapped Reads: 0
# Zero Length Reads: 0
# Total Reads Analyzed: 4351
# Reads Absent from Contig: 0
# Total Reads Contig: 4351

# %%
#dbc_nanopore
bamfile = "DVX9YH_fastq/dbc_nanopore_md.bam"
contig = "C-deltaBC-ITR"
filtered_count = 1585 
start_region = 2891
end_region = 3001
start_contig = 0
end_contig = 4949
frequency_pipeline(bamfile, contig, start_region, end_region, filtered_count, start_contig, end_contig, filtered_count)
# Out:
# Unmapped Reads: 0
# Zero Length Reads: 0
# Total Reads Analyzed: 1585
# Reads Absent from Contig: 0
# Total Reads Contig: 1585

# %%
#WT_Nanopore_nopmll
bamfile = "77XK98_fastq/wt_nopmll_nanopore_md.bam"
contig = "B-synITRWT"
filtered_count = 4323
start_region = 2925
end_region = 3069
start_contig = 0
end_contig = 5018
frequency_pipeline(bamfile, contig, start_region, end_region, filtered_count, start_contig, end_contig, filtered_count)
# Out:
# Unmapped Reads: 0
# Zero Length Reads: 0
# Total Reads Analyzed: 4323
# Reads Absent from Contig: 0
# Total Reads Contig: 4323

# %%
#dBC_Nanopore_nopmll
bamfile = "77XK98_fastq/dbc_nopmll_nanopore_md.bam"
contig = "C-deltaBC-ITR"
filtered_count = 2016
start_region = 2891
end_region = 3001
start_contig = 0
end_contig = 4949
frequency_pipeline(bamfile, contig, start_region, end_region, filtered_count, start_contig, end_contig, filtered_count)
# Out:
# Unmapped Reads: 0
# Zero Length Reads: 0
# Total Reads Analyzed: 2016
# Reads Absent from Contig: 0
# Total Reads Contig: 2016
